# %% [markdown]
# <a href="https://colab.research.google.com/github/jayaditya366/C-programs/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num=int(input("enter number :"));
print(num);
print(type(num))
# Out:
# enter number :121
# 121
# <class 'int'>

# %%
address=str("i come from my home which is located in old dairy farm 5-150 visakhapatnam")
##length of string
print(address)
print(type(address))
print(len(address))
# Out:
# i come from my home which is located in old dairy farm 5-150 visakhapatnam
# <class 'str'>
# 74

# %%
a = "Hello, World!"
##length of string
print(a[0])
print(len(a))
# Out:
# H
# 13

# %%
##if not
a="Eminem is Rap god"
print("Rap"in a,"adi" in a)
# Out:
# True False

# %%
##checking a string
a="cherry is tasty"
print("cherry" in a )
print("adi" in a)
print("tas" in a)
# Out:
# True
# False
# True

# %%
##slicing of a srtring
a="i went to rrr movie"
print(a[2],a[5],a[8],a[18],a[3:9],a[18:0])
print(a[17:3])
# Out:
# w t o e ent to

# %%
##reverse of a string

# %%
##modifing a string
a="rrr movie"
print(a.upper())#upper
print(a.lower())#lowe
print(a[7].upper)
# Out:
# RRR MOVIE
# rrr movie
# <built-in method upper of str object at 0x7f120b75d1f0>

# %%
##strip[to remove space]
a="                                                                                                            they see me rolling"
print(a.strip())
# Out:
# they see me rolling

# %%
##replacing a string
a="JAYADITYA"
print(a.replace("JAY",""))
# Out:
# ADITYA

# %%
##string concatination
a="JAY"
b="ADITYA"
c=print(a+b)
# Out:
# JAYADITYA

# %%
##string format
a="jayaditya"
b=18
c="my name is {} i am {} years old"
print(c.format(a,b))
# Out:
# my name is jayaditya i am 18 years old

# %%
##escape characters
a="jayaditya says \"HTML AND CSS\" are best for front-end web-dev"
print(a)
# Out:
# jayaditya says "HTML AND CSS" are best for front-end web-dev
