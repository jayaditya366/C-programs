# %% [markdown]
# <a href="https://colab.research.google.com/github/jayaditya366/C-programs/blob/main/Lists.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
fruit=["apple","pine","mango","grape","peace"]

fruit[-1]
print(fruit[-1])
print(fruit[0])
print(fruit)
print(fruit[3:])
print(len(fruit))
fruit.insert(2,"banana")
print(fruit)
fruit.reverse()
print(fruit)
fruit.sort()
print(fruit)
fruit.pop(3)
print(fruit)
print(len(fruit))
# Out:
# peace
# apple
# ['apple', 'pine', 'mango', 'grape', 'peace']
# ['grape', 'peace']
# 5
# ['apple', 'pine', 'banana', 'mango', 'grape', 'peace']
# ['peace', 'grape', 'mango', 'banana', 'pine', 'apple']
# ['apple', 'banana', 'grape', 'mango', 'peace', 'pine']
# ['apple', 'banana', 'grape', 'peace', 'pine']
# 5

# %%
lists=[12,"hi",3.45,'a']
print(lists[0])
print(lists[0:2])
print(lists[0]*lists[2])
print(lists[:3])
print(lists[:3])
print(lists[1:])
print(lists[:-3])
print(type(lists))
# Out:
# 12
# [12, 'hi']
# 41.400000000000006
# [12, 'hi', 3.45]
# [12, 'hi', 3.45]
# ['hi', 3.45, 'a']
# [12]
# <class 'list'>

# %%
# Nested List
n_list = ["Happy", [2, 0, 1, 5]]

# Nested indexing
print(n_list[0][1])


# Error! Only integer can be used for indexing
# Out:
# a
