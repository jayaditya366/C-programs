# %% [markdown]
# <a href="https://colab.research.google.com/github/jayaditya366/C-programs/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#find out the person is eligible for voting or not?(static)
a=5
print(type(a))

if a>=18 :
  print("you are eligile")
else :
  print("you are  not eligile")
# Out:
# <class 'int'>
# you are  not eligile

# %%
a=int(input(a))

if a>=18 :
  print("you are eligile")
else :
  print("you are  not eligile")
# Out:
# 45100
# you are eligile

# %%
#give 5 sub marks find greatest among 5
a=int(input("enter num1\n"))
b=int(input("enter num2\n"))
c=int(input("enter num3\n"))
d=int(input("enter num4\n"))
e=int(input("enter num5\n"))
if a>b and a>c and a>d and a>e :
  print("a is greatest\n")
elif b>a and b>c and b>d and b>e :
  print("b is greatest\n")
elif c>a and c>b and c>d and c>e :
  print("c is greatest\n")
elif d>a and d>b and d>c and d>e :
  print("d is greatest\n")
else :
  print("e is greatest\n4")
# Out:
# enter num1
# 55
# enter num2
# 5
# enter num3
# 44
# enter num4
# 78
# enter num5
# 125
# e is greatest

# %%
#check whether the triangle is isoscles or equal
a=int(input("enter sidde 1\n"))
b=int(input("enter side 2\n"))
c=int(input("enter side 3\n"))
if a==b==c :
  print("it is an equal triangle/n")
elif a==b!=c or a!=b==c or a!=c==b :
  print("it is an isosceles triangle")
# Out:
# enter sidde 1
# 25
# enter side 2
# 45
# enter side 3
# 95
