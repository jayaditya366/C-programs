# %% [markdown]
# <a href="https://colab.research.google.com/github/jayaditya366/C-programs/blob/main/strings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num=int(input("enter number :"));
print(num);
print(type(num))
# Out:
# enter number :121
# 121
# <class 'int'>

# %%
address=str("i come from my home which is located in old dairy farm 5-150 visakhapatnam")
print(address)
print(type(address))
# Out:
# i come from my home which is located in old dairy farm 5-150 visakhapatnam
# <class 'str'>
